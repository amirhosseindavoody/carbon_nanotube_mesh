# %%
import numpy as np
import matplotlib.pyplot as plt
import os.path
import os

% matplotlib inline

# %% [markdown]
# # Definition of tube class

# %%
class tube:
    x = np.zeros((0,3))
    def __init__(self, coordinates):
        for node in coordinates:
            node = node.split(',')
            if (len(node) is 3):
                a = np.array([float(item) for item in node])
                a = a.reshape((1,3))
                self.x = np.concatenate((self.x, a), axis=0)
    
    def avg_y(self):
        return np.mean(self.x[:,1])

# %% [markdown]
# # Check height of tubes

# %%
directory = "/Users/amirhossein/research/cnt_mesh_longer_bids"

tubes = []

for i in range(1,8):
    filename = os.path.join(directory, "tube"+str(i)+".dat")
    print("reading file: {}".format(filename))
    with open(filename) as file:
        for line in file:
            x = line.strip().split(";")
            x = x[1:]
            tubes.append(tube(x))

print("number of tubes: {}".format(len(tubes)))
avg_y = np.array([np.mean(tube.x[:,1]) for tube in tubes])

fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(1,1,1)
ax.plot(avg_y, linewidth=4)
ax.set_title("average position along y-axis in order of dropping",fontsize=30)
ax.set_xlabel("Drop order",fontsize=24)
ax.set_ylabel("Average y-coordinate [nm]",fontsize=24)
ax.tick_params(labelsize=20)
# Out:
# reading file: /Users/amirhossein/research/cnt_mesh_longer_bids/tube1.dat
# reading file: /Users/amirhossein/research/cnt_mesh_longer_bids/tube2.dat
# reading file: /Users/amirhossein/research/cnt_mesh_longer_bids/tube3.dat
# reading file: /Users/amirhossein/research/cnt_mesh_longer_bids/tube4.dat
# reading file: /Users/amirhossein/research/cnt_mesh_longer_bids/tube5.dat
# reading file: /Users/amirhossein/research/cnt_mesh_longer_bids/tube6.dat
# reading file: /Users/amirhossein/research/cnt_mesh_longer_bids/tube7.dat
# number of tubes: 67787
